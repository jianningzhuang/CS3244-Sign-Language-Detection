# %%
import os
import cv2
#import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import Adam

# %%
# Specify the height and width to which each video frame will be resized in our dataset.
IMAGE_HEIGHT , IMAGE_WIDTH = 128, 128

# Specify the number of frames of a video that will be fed to the model as one sequence.
SEQUENCE_LENGTH = 30

# Specify the directory containing the UCF50 dataset. 
DATASET_DIR = "Frame_data"

# Thirty videos worth of data
no_sequences = 50

# Specify the list containing the names of the classes used for training. Feel free to choose any set of classes.
CLASSES_LIST = ['Hi', 'I am', 'From', 'Singapore', 'Paiseh', 'I', 'Cannot', 'Speak', 'But', 'Machine', 'Learning', 'Can', 'Help', 'Translate']

# %%
label_map = {label:num for num, label in enumerate(CLASSES_LIST)}

# %%
def create_dataset():
    '''
    This function will extract the data of the selected classes and create the required dataset.
    Returns:
        features:          A list containing the extracted frames of the videos.
        labels:            A list containing the indexes of the classes associated with the videos.
        video_files_paths: A list containing the paths of the videos in the disk.
    '''

    # Declared Empty Lists to store the features, labels and video file path values.
    features = []
    labels = []
    video_files_paths = []
    
    # Iterating through all the classes mentioned in the classes list
    for class_index, class_name in enumerate(CLASSES_LIST):
        
        # Display the name of the class whose data is being extracted.
        print(f'Extracting Data of Class: {class_name}')
        
        # Get the list of video files present in the specific class name directory.
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        
        # Iterate through all the files present in the files list.
        for file_name in range(no_sequences):
            window = []
            for frame_num in range(SEQUENCE_LENGTH):
            
                # Get the complete video path.
                video_file_path = os.path.join(DATASET_DIR, class_name, str(file_name), str(frame_num)+".npy")

                # Extract the frames of the video file.
                frames = np.load(video_file_path) /255
                window.append(frames)

                # Check if the extracted frames are equal to the SEQUENCE_LENGTH specified above.
                # So ignore the vides having frames less than the SEQUENCE_LENGTH.

                # Append the data to their repective lists.
            features.append(window)
            labels.append(label_map[class_name])
            #video_files_paths.append(video_file_path)

    # Converting the list to numpy arrays
    features = np.asarray(features)
    labels = np.array(labels)  
    
    # Return the frames, class index, and video file path.
    return features, labels

# %%
features, labels = create_dataset()
one_hot_encoded_labels = to_categorical(labels)
# Out:
# Extracting Data of Class: Hi
# Extracting Data of Class: I am
# Extracting Data of Class: From
# Extracting Data of Class: Singapore
# Extracting Data of Class: Paiseh
# Extracting Data of Class: I
# Extracting Data of Class: Cannot
# Extracting Data of Class: Speak
# Extracting Data of Class: But
# Extracting Data of Class: Machine
# Extracting Data of Class: Learning
# Extracting Data of Class: Can
# Extracting Data of Class: Help
# Extracting Data of Class: Translate

# %%
def create_convlstm_model():
    '''
    This function will construct the required convlstm model.
    Returns:
        model: It is the required constructed convlstm model.
    '''

    # We will use a Sequential model for model construction
    model = Sequential()

    # Define the Model Architecture.
    ########################################################################################################################
    
    model.add(ConvLSTM2D(filters = 4, kernel_size = (3, 3), activation = 'tanh',data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True, input_shape = (SEQUENCE_LENGTH,
                                                                                      IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 8, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 14, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(ConvLSTM2D(filters = 16, kernel_size = (3, 3), activation = 'tanh', data_format = "channels_last",
                         recurrent_dropout=0.2, return_sequences=True))
    
    model.add(MaxPooling3D(pool_size=(1, 2, 2), padding='same', data_format='channels_last'))
    #model.add(TimeDistributed(Dropout(0.2)))
    
    model.add(Flatten()) 
    
    model.add(Dense(len(CLASSES_LIST), activation = "softmax"))
    
    ########################################################################################################################
     
    # Display the models summary.
    model.summary()
    
    # Return the constructed convlstm model.
    return model

# %%
accuracies = []
f1_scores = []
precisions = []
recalls = []

kf = KFold(n_splits=5, shuffle=True)
for train_index, test_index in kf.split(features):
    
    np.random.shuffle(train_index)
    np.random.shuffle(test_index)
    
    features_train, features_test = features[train_index], features[test_index]
    labels_train, labels_test = one_hot_encoded_labels[train_index], one_hot_encoded_labels[test_index]
    
    # Construct the required LRCN model.
    convlstm_model = create_convlstm_model()

    # Display the success message.
    print("Model Created Successfully!")
    
    # Create an Instance of Early Stopping Callback
    early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 10, mode = 'min', restore_best_weights = True)

    # Compile the model and specify loss function, optimizer and metrics values to the model
    convlstm_model.compile(loss = 'categorical_crossentropy', optimizer = "Adam", metrics = ["accuracy"])

    # Start training the model.
    convlstm_model_training_history = convlstm_model.fit(x = features_train, y = labels_train, epochs = 50, batch_size = 4,
                                                         shuffle = True, validation_split = 0.2, 
                                                         callbacks = [early_stopping_callback])

    # Evaluate the trained model.
    predictions = convlstm_model.predict(features_test)
    y_true = np.argmax(labels_test, axis=1).tolist()
    y_hat = np.argmax(predictions, axis=1).tolist()
    conf = multilabel_confusion_matrix(y_true,y_hat)
    acc = accuracy_score(y_true, y_hat)
    
    indiv_f1 = []
    indiv_pre = []
    indiv_re = []
    for matrix in conf:
        FP = matrix[0][1]
        FN = matrix[1][0]
        TP = matrix[1][1]
        precision = TP/(TP+FP)
        recall = TP/(TP+FN)
        indiv_f1.append((2*precision*recall)/(precision+recall))
        indiv_pre.append(precision)
        indiv_re.append(recall)
    f1 = np.nansum(indiv_f1)/len(indiv_f1)
    pre = np.nansum(indiv_pre)/len(indiv_pre)
    re = np.nansum(indiv_re)/len(indiv_re)
    
    accuracies.append(acc)
    f1_scores.append(f1)
    precisions.append(pre)
    recalls.append(re)
    
    print(acc)
    print(f1)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  time_distributed (TimeDistr  (None, 30, 128, 128, 16)  448
#  ibuted)
#
#  time_distributed_1 (TimeDis  (None, 30, 32, 32, 16)   0
#  tributed)
#
#  time_distributed_2 (TimeDis  (None, 30, 32, 32, 16)   0
#  tributed)
#
#  time_distributed_3 (TimeDis  (None, 30, 32, 32, 32)   4640
#  tributed)
#
#  time_distributed_4 (TimeDis  (None, 30, 8, 8, 32)     0
#  tributed)
#
#  time_distributed_5 (TimeDis  (None, 30, 8, 8, 32)     0
#  tributed)
#
#  time_distributed_6 (TimeDis  (None, 30, 8, 8, 64)     18496
#  tributed)
#
#  time_distributed_7 (TimeDis  (None, 30, 4, 4, 64)     0
#  tributed)
#
#  time_distributed_8 (TimeDis  (None, 30, 4, 4, 64)     0
#  tributed)
#
#  time_distributed_9 (TimeDis  (None, 30, 4, 4, 64)     36928
#  tributed)
#
#  time_distributed_10 (TimeDi  (None, 30, 2, 2, 64)     0
#  stributed)
#
#  time_distributed_11 (TimeDi  (None, 30, 256)          0
#  stributed)
#
#  lstm (LSTM)                 (None, 32)                36992
#
#  dense (Dense)               (None, 14)                462
#
# =================================================================
# Total params: 97,966
# Trainable params: 97,966
# Non-trainable params: 0
# _________________________________________________________________
# Model Created Successfully!
# Epoch 1/120
# 112/112 [==============================] - 51s 430ms/step - loss: 2.6653 - accuracy: 0.0580 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6414 - val_accuracy: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/120
# 112/112 [==============================] - 43s 383ms/step - loss: 2.6409 - accuracy: 0.0781 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6428 - val_accuracy: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/120
# 112/112 [==============================] - 40s 358ms/step - loss: 2.6410 - accuracy: 0.0714 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6430 - val_accuracy: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/120
# 112/112 [==============================] - 39s 352ms/step - loss: 2.6415 - accuracy: 0.0513 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6441 - val_accuracy: 0.0625 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/120
# 112/112 [==============================] - 38s 339ms/step - loss: 2.6381 - accuracy: 0.0893 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6479 - val_accuracy: 0.0714 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/120
# 112/112 [==============================] - 36s 325ms/step - loss: 2.6419 - accuracy: 0.0759 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6404 - val_accuracy: 0.0893 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/120
# 112/112 [==============================] - 34s 302ms/step - loss: 2.6387 - accuracy: 0.0737 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6102 - val_accuracy: 0.1161 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/120
# 112/112 [==============================] - 35s 314ms/step - loss: 2.4929 - accuracy: 0.1317 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.3202 - val_accuracy: 0.2768 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/120
# 112/112 [==============================] - 33s 296ms/step - loss: 2.2200 - accuracy: 0.2388 - precision: 0.7500 - recall: 0.0134 - val_loss: 2.2879 - val_accuracy: 0.2411 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/120
# 112/112 [==============================] - 30s 268ms/step - loss: 1.8909 - accuracy: 0.3527 - precision: 0.7600 - recall: 0.0424 - val_loss: 2.2398 - val_accuracy: 0.2321 - val_precision: 0.8889 - val_recall: 0.0714
# Epoch 11/120
# 112/112 [==============================] - 29s 262ms/step - loss: 1.7401 - accuracy: 0.3772 - precision: 0.7586 - recall: 0.0982 - val_loss: 2.0332 - val_accuracy: 0.3393 - val_precision: 0.7000 - val_recall: 0.1250
# Epoch 12/120
# 112/112 [==============================] - 29s 261ms/step - loss: 1.5594 - accuracy: 0.4844 - precision: 0.7900 - recall: 0.1763 - val_loss: 1.5938 - val_accuracy: 0.4911 - val_precision: 0.6154 - val_recall: 0.2143
# Epoch 13/120
# 112/112 [==============================] - 30s 265ms/step - loss: 1.2809 - accuracy: 0.5871 - precision: 0.8280 - recall: 0.2902 - val_loss: 1.4096 - val_accuracy: 0.5446 - val_precision: 0.8333 - val_recall: 0.2232
# Epoch 14/120
# 112/112 [==============================] - 35s 310ms/step - loss: 1.1774 - accuracy: 0.6138 - precision: 0.8393 - recall: 0.3147 - val_loss: 1.2830 - val_accuracy: 0.6071 - val_precision: 0.8537 - val_recall: 0.3125
# Epoch 15/120
# 112/112 [==============================] - 39s 349ms/step - loss: 1.0570 - accuracy: 0.6451 - precision: 0.8843 - recall: 0.4263 - val_loss: 1.1008 - val_accuracy: 0.6518 - val_precision: 0.8644 - val_recall: 0.4554
# Epoch 16/120
# 112/112 [==============================] - 37s 334ms/step - loss: 0.9812 - accuracy: 0.6897 - precision: 0.9234 - recall: 0.4844 - val_loss: 1.0940 - val_accuracy: 0.6518 - val_precision: 0.8833 - val_recall: 0.4732
# Epoch 17/120
# 112/112 [==============================] - 36s 323ms/step - loss: 0.8517 - accuracy: 0.7277 - precision: 0.9077 - recall: 0.5491 - val_loss: 0.9728 - val_accuracy: 0.7232 - val_precision: 0.9054 - val_recall: 0.5982
# Epoch 18/120
# 112/112 [==============================] - 31s 274ms/step - loss: 0.6999 - accuracy: 0.8147 - precision: 0.9204 - recall: 0.6451 - val_loss: 0.8690 - val_accuracy: 0.7321 - val_precision: 0.8800 - val_recall: 0.5893
# Epoch 19/120
# 112/112 [==============================] - 31s 275ms/step - loss: 0.5724 - accuracy: 0.8616 - precision: 0.9497 - recall: 0.7165 - val_loss: 0.8377 - val_accuracy: 0.7411 - val_precision: 0.8471 - val_recall: 0.6429
# Epoch 20/120
# 112/112 [==============================] - 32s 286ms/step - loss: 0.5270 - accuracy: 0.8728 - precision: 0.9591 - recall: 0.7857 - val_loss: 0.7624 - val_accuracy: 0.7768 - val_precision: 0.9091 - val_recall: 0.7143
# Epoch 21/120
# 112/112 [==============================] - 30s 265ms/step - loss: 0.4889 - accuracy: 0.8772 - precision: 0.9667 - recall: 0.7768 - val_loss: 0.8095 - val_accuracy: 0.7500 - val_precision: 0.9012 - val_recall: 0.6518
# Epoch 22/120
# 112/112 [==============================] - 31s 273ms/step - loss: 0.7007 - accuracy: 0.7879 - precision: 0.9039 - recall: 0.6719 - val_loss: 1.0238 - val_accuracy: 0.6964 - val_precision: 0.8506 - val_recall: 0.6607
# Epoch 23/120
# 112/112 [==============================] - 31s 279ms/step - loss: 0.4808 - accuracy: 0.8705 - precision: 0.9388 - recall: 0.7879 - val_loss: 0.6118 - val_accuracy: 0.8482 - val_precision: 0.9247 - val_recall: 0.7679
# Epoch 24/120
# 112/112 [==============================] - 31s 276ms/step - loss: 0.3649 - accuracy: 0.9174 - precision: 0.9549 - recall: 0.8504 - val_loss: 0.5434 - val_accuracy: 0.8661 - val_precision: 0.8980 - val_recall: 0.7857
# Epoch 25/120
# 112/112 [==============================] - 30s 268ms/step - loss: 0.3620 - accuracy: 0.9018 - precision: 0.9620 - recall: 0.8482 - val_loss: 0.6125 - val_accuracy: 0.8304 - val_precision: 0.9022 - val_recall: 0.7411
# Epoch 26/120
# 112/112 [==============================] - 31s 277ms/step - loss: 0.3304 - accuracy: 0.9152 - precision: 0.9513 - recall: 0.8728 - val_loss: 0.5789 - val_accuracy: 0.8393 - val_precision: 0.8654 - val_recall: 0.8036
# Epoch 27/120
# 112/112 [==============================] - 31s 275ms/step - loss: 0.2655 - accuracy: 0.9420 - precision: 0.9710 - recall: 0.8973 - val_loss: 0.5243 - val_accuracy: 0.8393 - val_precision: 0.8900 - val_recall: 0.7946
# Epoch 28/120
# 112/112 [==============================] - 33s 292ms/step - loss: 0.3040 - accuracy: 0.9263 - precision: 0.9685 - recall: 0.8929 - val_loss: 0.4978 - val_accuracy: 0.8482 - val_precision: 0.9126 - val_recall: 0.8393
# Epoch 29/120
# 112/112 [==============================] - 36s 320ms/step - loss: 0.2893 - accuracy: 0.9397 - precision: 0.9679 - recall: 0.8750 - val_loss: 0.4237 - val_accuracy: 0.8929 - val_precision: 0.9600 - val_recall: 0.8571
# Epoch 30/120
# 112/112 [==============================] - 32s 282ms/step - loss: 0.1996 - accuracy: 0.9598 - precision: 0.9791 - recall: 0.9397 - val_loss: 0.4753 - val_accuracy: 0.8750 - val_precision: 0.8932 - val_recall: 0.8214
# Epoch 31/120
# 112/112 [==============================] - 31s 279ms/step - loss: 0.1948 - accuracy: 0.9576 - precision: 0.9791 - recall: 0.9420 - val_loss: 0.4251 - val_accuracy: 0.9018 - val_precision: 0.9340 - val_recall: 0.8839
# Epoch 32/120
# 112/112 [==============================] - 31s 277ms/step - loss: 0.1714 - accuracy: 0.9688 - precision: 0.9816 - recall: 0.9509 - val_loss: 0.4507 - val_accuracy: 0.8929 - val_precision: 0.9143 - val_recall: 0.8571
# Epoch 33/120
# 112/112 [==============================] - 31s 279ms/step - loss: 0.2156 - accuracy: 0.9509 - precision: 0.9696 - recall: 0.9241 - val_loss: 0.3709 - val_accuracy: 0.8929 - val_precision: 0.9252 - val_recall: 0.8839
# Epoch 34/120
# 112/112 [==============================] - 31s 278ms/step - loss: 0.1946 - accuracy: 0.9531 - precision: 0.9764 - recall: 0.9241 - val_loss: 0.4927 - val_accuracy: 0.8661 - val_precision: 0.8796 - val_recall: 0.8482
# Epoch 35/120
# 112/112 [==============================] - 30s 272ms/step - loss: 0.2356 - accuracy: 0.9375 - precision: 0.9580 - recall: 0.9174 - val_loss: 0.3892 - val_accuracy: 0.8839 - val_precision: 0.9307 - val_recall: 0.8393
# Epoch 36/120
# 112/112 [==============================] - 31s 276ms/step - loss: 0.1559 - accuracy: 0.9688 - precision: 0.9793 - recall: 0.9487 - val_loss: 0.4094 - val_accuracy: 0.8839 - val_precision: 0.9216 - val_recall: 0.8393
# Epoch 37/120
# 112/112 [==============================] - 31s 279ms/step - loss: 0.1411 - accuracy: 0.9621 - precision: 0.9814 - recall: 0.9442 - val_loss: 0.3781 - val_accuracy: 0.9107 - val_precision: 0.9314 - val_recall: 0.8482
# Epoch 38/120
# 112/112 [==============================] - 32s 287ms/step - loss: 0.0938 - accuracy: 0.9866 - precision: 0.9955 - recall: 0.9777 - val_loss: 0.3262 - val_accuracy: 0.9018 - val_precision: 0.9429 - val_recall: 0.8839
# Epoch 39/120
# 112/112 [==============================] - 34s 299ms/step - loss: 0.1340 - accuracy: 0.9621 - precision: 0.9703 - recall: 0.9464 - val_loss: 0.4698 - val_accuracy: 0.8929 - val_precision: 0.9300 - val_recall: 0.8304
# Epoch 40/120
# 112/112 [==============================] - 34s 308ms/step - loss: 0.1606 - accuracy: 0.9665 - precision: 0.9794 - recall: 0.9531 - val_loss: 0.2999 - val_accuracy: 0.9464 - val_precision: 0.9619 - val_recall: 0.9018
# Epoch 41/120
# 112/112 [==============================] - 33s 299ms/step - loss: 0.0861 - accuracy: 0.9888 - precision: 0.9955 - recall: 0.9799 - val_loss: 0.3764 - val_accuracy: 0.9107 - val_precision: 0.9510 - val_recall: 0.8661
# Epoch 42/120
# 112/112 [==============================] - 41s 369ms/step - loss: 0.0826 - accuracy: 0.9888 - precision: 0.9887 - recall: 0.9777 - val_loss: 0.2660 - val_accuracy: 0.9464 - val_precision: 0.9623 - val_recall: 0.9107
# Epoch 43/120
# 112/112 [==============================] - 41s 368ms/step - loss: 0.0818 - accuracy: 0.9844 - precision: 0.9932 - recall: 0.9754 - val_loss: 0.3177 - val_accuracy: 0.9464 - val_precision: 0.9533 - val_recall: 0.9107
# Epoch 44/120
# 112/112 [==============================] - 40s 359ms/step - loss: 0.0610 - accuracy: 0.9955 - precision: 0.9977 - recall: 0.9866 - val_loss: 0.3033 - val_accuracy: 0.9286 - val_precision: 0.9450 - val_recall: 0.9196
# Epoch 45/120
# 112/112 [==============================] - 34s 305ms/step - loss: 0.0654 - accuracy: 0.9866 - precision: 0.9910 - recall: 0.9821 - val_loss: 0.2609 - val_accuracy: 0.9554 - val_precision: 0.9626 - val_recall: 0.9196
# Epoch 46/120
# 112/112 [==============================] - 31s 276ms/step - loss: 0.1508 - accuracy: 0.9665 - precision: 0.9794 - recall: 0.9554 - val_loss: 0.5028 - val_accuracy: 0.8393 - val_precision: 0.8611 - val_recall: 0.8304
# Epoch 47/120
# 112/112 [==============================] - 30s 264ms/step - loss: 0.1810 - accuracy: 0.9509 - precision: 0.9724 - recall: 0.9442 - val_loss: 0.3959 - val_accuracy: 0.9107 - val_precision: 0.9083 - val_recall: 0.8839
# Epoch 48/120
# 112/112 [==============================] - 32s 285ms/step - loss: 0.0836 - accuracy: 0.9866 - precision: 0.9910 - recall: 0.9844 - val_loss: 0.2553 - val_accuracy: 0.9554 - val_precision: 0.9720 - val_recall: 0.9286
# Epoch 49/120
# 112/112 [==============================] - 32s 285ms/step - loss: 0.0611 - accuracy: 0.9866 - precision: 0.9977 - recall: 0.9866 - val_loss: 0.2798 - val_accuracy: 0.9286 - val_precision: 0.9528 - val_recall: 0.9018
# Epoch 50/120
# 112/112 [==============================] - 33s 295ms/step - loss: 0.0631 - accuracy: 0.9888 - precision: 0.9888 - recall: 0.9866 - val_loss: 0.3114 - val_accuracy: 0.9286 - val_precision: 0.9439 - val_recall: 0.9018
# Epoch 51/120
# 112/112 [==============================] - 33s 295ms/step - loss: 0.3286 - accuracy: 0.8973 - precision: 0.9200 - recall: 0.8728 - val_loss: 0.5163 - val_accuracy: 0.8661 - val_precision: 0.8774 - val_recall: 0.8304
# Epoch 52/120
# 112/112 [==============================] - 33s 291ms/step - loss: 0.2579 - accuracy: 0.9375 - precision: 0.9534 - recall: 0.9129 - val_loss: 0.7172 - val_accuracy: 0.7679 - val_precision: 0.7830 - val_recall: 0.7411
# Epoch 53/120
# 112/112 [==============================] - 32s 288ms/step - loss: 0.3009 - accuracy: 0.9018 - precision: 0.9333 - recall: 0.8750 - val_loss: 0.5365 - val_accuracy: 0.8571 - val_precision: 0.8636 - val_recall: 0.8482
# Epoch 54/120
# 112/112 [==============================] - 36s 324ms/step - loss: 0.0877 - accuracy: 0.9911 - precision: 0.9932 - recall: 0.9732 - val_loss: 0.3661 - val_accuracy: 0.9107 - val_precision: 0.9091 - val_recall: 0.8929
# Epoch 55/120
# 112/112 [==============================] - 36s 323ms/step - loss: 0.0529 - accuracy: 0.9933 - precision: 0.9978 - recall: 0.9933 - val_loss: 0.3156 - val_accuracy: 0.9196 - val_precision: 0.9279 - val_recall: 0.9196
# Epoch 56/120
# 112/112 [==============================] - 38s 337ms/step - loss: 0.0397 - accuracy: 0.9978 - precision: 0.9978 - recall: 0.9933 - val_loss: 0.4277 - val_accuracy: 0.8750 - val_precision: 0.8727 - val_recall: 0.8571
# Epoch 57/120
# 112/112 [==============================] - 40s 362ms/step - loss: 0.0424 - accuracy: 0.9888 - precision: 0.9933 - recall: 0.9888 - val_loss: 0.3150 - val_accuracy: 0.9286 - val_precision: 0.9444 - val_recall: 0.9107
# Epoch 58/120
# 112/112 [==============================] - 38s 338ms/step - loss: 0.0416 - accuracy: 0.9933 - precision: 0.9955 - recall: 0.9888 - val_loss: 0.3316 - val_accuracy: 0.9196 - val_precision: 0.9189 - val_recall: 0.9107
# Epoch 59/120
# 112/112 [==============================] - 32s 285ms/step - loss: 0.0460 - accuracy: 0.9911 - precision: 0.9933 - recall: 0.9888 - val_loss: 0.3134 - val_accuracy: 0.9196 - val_precision: 0.9279 - val_recall: 0.9196
# Epoch 60/120
# 112/112 [==============================] - 30s 270ms/step - loss: 0.0423 - accuracy: 0.9933 - precision: 0.9933 - recall: 0.9933 - val_loss: 0.3428 - val_accuracy: 0.9107 - val_precision: 0.9182 - val_recall: 0.9018
# Epoch 61/120
# 112/112 [==============================] - 30s 265ms/step - loss: 0.0343 - accuracy: 0.9955 - precision: 0.9978 - recall: 0.9911 - val_loss: 0.2445 - val_accuracy: 0.9375 - val_precision: 0.9375 - val_recall: 0.9375
# Epoch 62/120
# 112/112 [==============================] - 32s 286ms/step - loss: 0.0529 - accuracy: 0.9911 - precision: 0.9911 - recall: 0.9888 - val_loss: 0.3458 - val_accuracy: 0.9196 - val_precision: 0.9273 - val_recall: 0.9107
# Epoch 63/120
# 112/112 [==============================] - 34s 303ms/step - loss: 0.0615 - accuracy: 0.9866 - precision: 0.9865 - recall: 0.9821 - val_loss: 0.2706 - val_accuracy: 0.9286 - val_precision: 0.9273 - val_recall: 0.9107
# Epoch 64/120
# 112/112 [==============================] - 35s 310ms/step - loss: 0.0699 - accuracy: 0.9777 - precision: 0.9820 - recall: 0.9732 - val_loss: 0.3180 - val_accuracy: 0.9196 - val_precision: 0.9266 - val_recall: 0.9018
# Epoch 65/120
# 112/112 [==============================] - 35s 312ms/step - loss: 0.1018 - accuracy: 0.9821 - precision: 0.9886 - recall: 0.9688 - val_loss: 0.3728 - val_accuracy: 0.9107 - val_precision: 0.9174 - val_recall: 0.8929
# Epoch 66/120
# 112/112 [==============================] - 33s 294ms/step - loss: 0.0875 - accuracy: 0.9799 - precision: 0.9865 - recall: 0.9754 - val_loss: 0.4939 - val_accuracy: 0.8661 - val_precision: 0.9223 - val_recall: 0.8482
# Epoch 67/120
# 112/112 [==============================] - 34s 301ms/step - loss: 0.1758 - accuracy: 0.9487 - precision: 0.9632 - recall: 0.9353 - val_loss: 0.4089 - val_accuracy: 0.8750 - val_precision: 0.8727 - val_recall: 0.8571
# Epoch 68/120
#  92/112 [=======================>......] - ETA: 5s - loss: 0.0579 - accuracy: 0.9864 - precision: 0.9864 - recall: 0.9864

# %%
print("Accuracies:", accuracies)
print("F1 Scores:", f1_scores)
print("Precisions:", precisions)
print("Recalls:", recalls)

# %%
print("Mean Accuracy:", np.nansum(accuracies)/len(accuracies))
print("Mean F1 Score:", np.nansum(f1_scores)/len(f1_scores))
print("Mean Precision:", np.nansum(precisions)/len(precisions))
print("Mean Recall:", np.nansum(recalls)/len(recalls))
